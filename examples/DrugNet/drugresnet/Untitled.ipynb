# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=plt.imread('/Users/Future/Desktop/Proposal/All_Drugs_Accuracy.png')
# plt.figure(figsize=(15, 10))
imgplot = plt.imshow(img)
plt.show()
